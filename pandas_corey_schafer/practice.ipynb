# %%
data = {
    'first_name' : ['Corey','Jake','Moris'],
    'last_name' : ['Schafer','Paul','Nolan'],
    'age' : [32,30,17],
    'email' : ['coreyschafer@gmail.com','jakepaul@gmail.com','morisnolan@gmail.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   first_name last_name  age                   email
# 0      Corey   Schafer   32  coreyschafer@gmail.com
# 1       Jake      Paul   30      jakepaul@gmail.com
# 2      Moris     Nolan   17    morisnolan@gmail.com

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'age', 'email'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  3 non-null      object
#  1   last_name   3 non-null      object
#  2   age         3 non-null      int64
#  3   email       3 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 224.0+ bytes

# %%
df.describe()
# Out:
#              age
# count   3.000000
# mean   26.333333
# std     8.144528
# min    17.000000
# 25%    23.500000
# 50%    30.000000
# 75%    31.000000
# max    32.000000

# %%
df.loc[[0,1]]
# Out:
#   first_name last_name  age                   email
# 0      Corey   Schafer   32  coreyschafer@gmail.com
# 1       Jake      Paul   30      jakepaul@gmail.com

# %%
df.shape
# Out:
# (3, 4)

# %%
df.head(1)
# Out:
#   first_name last_name  age                   email
# 0      Corey   Schafer   32  coreyschafer@gmail.com

# %%
df.tail(1)
# Out:
#   first_name last_name  age                 email
# 2      Moris     Nolan   17  morisnolan@gmail.com

# %%
df['email']
# Out:
# 0    coreyschafer@gmail.com
# 1        jakepaul@gmail.com
# 2      morisnolan@gmail.com
# Name: email, dtype: object

# %%
df.dtypes
# Out:
# first_name    object
# last_name     object
# age            int64
# email         object
# dtype: object

# %%
type(df['email'])
# Out:
# pandas.core.series.Series

# %%
#df.loc[0,'email']
df.iloc[0,3]
# Out:
# 'coreyschafer@gmail.com'

# %%
#df.loc[[0,1],'email']
df.iloc[[0,1],3]
# Out:
# 0    coreyschafer@gmail.com
# 1        jakepaul@gmail.com
# Name: email, dtype: object

# %%
df.set_index('email',inplace=True)

# %%
df
# Out:
#                        first_name last_name  age
# email
# coreyschafer@gmail.com      Corey   Schafer   32
# jakepaul@gmail.com           Jake      Paul   30
# morisnolan@gmail.com        Moris     Nolan   17

# %%
#df.loc['coreyschafer@gmail.com','age']
df.iloc[1,2]
# Out:
# 30

# %%
#df.loc[['coreyschafer@gmail.com','jakepaul@gmail.com'],'age']
df.iloc[[0,1],2]
# Out:
# email
# coreyschafer@gmail.com    32
# jakepaul@gmail.com        30
# Name: age, dtype: int64

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                     email first_name last_name  age
# 0  coreyschafer@gmail.com      Corey   Schafer   32
# 1      jakepaul@gmail.com       Jake      Paul   30
# 2    morisnolan@gmail.com      Moris     Nolan   17

# %%
df.loc[0,'email']
# Out:
# 'coreyschafer@gmail.com'

# %%
df.sort_index()
# Out:
#                     email first_name last_name  age
# 0  coreyschafer@gmail.com      Corey   Schafer   32
# 1      jakepaul@gmail.com       Jake      Paul   30
# 2    morisnolan@gmail.com      Moris     Nolan   17

# %%
df2 = pd.read_csv('survey_results_public.csv')

# %%
df2
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
df2.shape
# Out:
# (83439, 48)

# %%
df2.describe()
# Out:
#          ResponseId     CompTotal  ConvertedCompYearly
# count  83439.000000  4.718300e+04         4.684400e+04
# mean   41720.000000  2.119407e+69         1.184262e+05
# std    24086.908893  4.603702e+71         5.272944e+05
# min        1.000000  0.000000e+00         1.000000e+00
# 25%    20860.500000  1.600000e+04         2.702500e+04
# 50%    41720.000000  6.700000e+04         5.621100e+04
# 75%    62579.500000  1.400000e+05         1.000000e+05
# max    83439.000000  1.000000e+74         4.524131e+07

# %%
df2.dtypes
# Out:
# ResponseId                        int64
# MainBranch                       object
# Employment                       object
# Country                          object
# US_State                         object
# UK_Country                       object
# EdLevel                          object
# Age1stCode                       object
# LearnCode                        object
# YearsCode                        object
# YearsCodePro                     object
# DevType                          object
# OrgSize                          object
# Currency                         object
# CompTotal                       float64
# CompFreq                         object
# LanguageHaveWorkedWith           object
# LanguageWantToWorkWith           object
# DatabaseHaveWorkedWith           object
# DatabaseWantToWorkWith           object
# PlatformHaveWorkedWith           object
# PlatformWantToWorkWith           object
# WebframeHaveWorkedWith           object
# ...

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=83439, step=1)

# %%
df2.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
#df2.loc[0,'MainBranch']
df2.iloc[0,1]
# Out:
# 'I am a developer by profession'

# %%
#df2.loc[[0,1],'MainBranch']
df2.iloc[[0,1],1]
# Out:
# 0            I am a developer by profession
# 1    I am a student who is learning to code
# Name: MainBranch, dtype: object

# %%
df2.set_index('ResponseId',inplace=True)

# %%
df2
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df2
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
#df2.loc[1,'Country'] #1 here is the ResponseId
df2.iloc[0,2]
# Out:
# 'Slovakia'

# %%
#df2.loc[[1,2,3],'Country'] #1,2,3 is the responseid
df2.iloc[[0,1,2],2]
# Out:
# ResponseId
# 1              Slovakia
# 2           Netherlands
# 3    Russian Federation
# Name: Country, dtype: object

# %%
df2.reset_index(inplace=True)

# %%
df2
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.sort_values(by='last_name',ascending=False,inplace=True)

# %%
df.sort_values(by=['last_name','first_name'],inplace=True,ascending=[True,False])

# %%
df
# Out:
#                     email first_name last_name  age
# 2    morisnolan@gmail.com      Moris     Nolan   17
# 1      jakepaul@gmail.com       Jake      Paul   30
# 0  coreyschafer@gmail.com      Corey   Schafer   32

# %%
df['last_name']= df['last_name'].sort_values()

# %%
df
# Out:
#                     email first_name last_name  age
# 2    morisnolan@gmail.com      Moris     Nolan   17
# 1      jakepaul@gmail.com       Jake      Paul   30
# 0  coreyschafer@gmail.com      Corey   Schafer   32

# %%
df2
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
filt = df2['Country'] == 'India'

# %%
df2.loc[filt,'Age']
# Out:
# 8           25-34 years old
# 22       Under 18 years old
# 39          18-24 years old
# 49          18-24 years old
# 52          25-34 years old
#                 ...
# 83399       25-34 years old
# 83406       18-24 years old
# 83410       18-24 years old
# 83411       25-34 years old
# 83417       18-24 years old
# Name: Age, Length: 10511, dtype: object

# %%
filt = (df2['Country'] == 'India') & (df2['LanguageHaveWorkedWith'])

# %%
df2.loc[filt]
# Out:
#        ResponseId                              MainBranch          Employment  \
# 8               9          I am a developer by profession  Employed part-time
# 22             23  I am a student who is learning to code  Student, full-time
# 39             40  I am a student who is learning to code  Student, part-time
# 49             50  I am a student who is learning to code  Student, full-time
# 52             53          I am a developer by profession  Employed full-time
# ...           ...                                     ...                 ...
# 83399       83400          I am a developer by profession  Employed full-time
# 83406       83407  I am a student who is learning to code  Student, full-time
# 83410       83411  I am a student who is learning to code  Student, part-time
# 83411       83412          I am a developer by profession  Employed full-time
# 83417       83418          I am a developer by profession  Student, full-time
#
# ...

# %%
filt = (df2['Country'] == 'India') | (df2['LanguageHaveWorkedWith'] == "Python")

# %%
df2.loc[filt,'ResponseId']
# Out:
# 8            9
# 22          23
# 27          28
# 39          40
# 49          50
#          ...
# 83399    83400
# 83406    83407
# 83410    83411
# 83411    83412
# 83417    83418
# Name: ResponseId, Length: 11556, dtype: int64

# %%
filt = df2['Age']

# %%
filt.value_counts()
# Out:
# 25-34 years old       32568
# 18-24 years old       20993
# 35-44 years old       15183
# 45-54 years old        5472
# Under 18 years old     5376
# 55-64 years old        1819
# Prefer not to say       575
# 65 years or older       421
# Name: Age, dtype: int64

# %%
filt = df2['Age']

# %%
df2[filt]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-c54c8ef8b9f2> in <module>
# ----> 1 df2[filt]
#
# c:\essentials\python\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# c:\essentials\python\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ...

# %%
df2['Age'].value_counts()

# %%
df['full_name'] = df['first_name'] + ' ' + df['last_name']

# %%
df

# %%
df.drop(columns=['first_name','last_name'],inplace=True)

# %%
df

# %%
df[['first_name','last_name']] = df['full_name'].str.split(' ',expand=True)

# %%
df

# %%
df.drop(columns=['full_name'])

# %%
people2= {
    'first': ['Tony', 'Steve'], 
    'last': ['Stark', 'Rogers'], 
    'email': ['IronMan@avenge.com', 'Cap@avenge.com']
}

# %%
df3 = pd.DataFrame(people2)

# %%
df.append(df3)

# %%
df

# %%
dataset = {
    'Name' : ['Aryan','Pawan','Vishnu'],
    'Age' : [18,35,17],
    'Skill' : ['Coder','Bussinessman','Startup-owner']
}

# %%
df3= pd.DataFrame(dataset)

# %%
df3
# Out:
#      Name  Age          Skill
# 0   Aryan   18          Coder
# 1   Pawan   35   Bussinessman
# 2  Vishnu   17  Startup-owner

# %%
df3.columns
# Out:
# Index(['Name', 'Age', 'Skill', 'Umar'], dtype='object')

# %%
df3.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df3.rename(columns = {'Age':'Umar','Skill':'SourceOfIncome'},inplace=True)

# %%
df3
# Out:
#      Name  Umar SourceOfIncome  Umar
# 0   Aryan    18          Coder   NaN
# 1   Pawan    35   Bussinessman  69.0
# 2  Vishnu    17  Startup-owner   NaN

# %%
df3.loc[0]
# Out:
# Name              Aryan
# Umar                 18
# SourceOfIncome    Coder
# Umar                NaN
# Name: 0, dtype: object

# %%
df3.loc[0,['Name','Umar']] =['Aryan',17]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-088b72bd01e1> in <module>
# ----> 1 df3.loc[0,['Name','Umar']] =['Aryan',17]
#
# c:\essentials\python\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 692         iloc._setitem_with_indexer(indexer, value, self.name)
#     693
#     694     def _validate_key(self, key, axis: int):
#
# c:\essentials\python\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1633         if take_split_path:
#    1634             # We have to operate column-wise
# -> 1635             self._setitem_with_indexer_split_path(indexer, value, name)
#    1636         else:
#    1637             self._setitem_single_block(indexer, value, name)
#
# ...

# %%
df3
# Out:
#      Name  Umar SourceOfIncome  Umar
# 0   Aryan    18          Coder   NaN
# 1   Pawan    35   Bussinessman  69.0
# 2  Vishnu    17  Startup-owner   NaN

# %%
df3.loc[0] = ['Aryannn',16,'Noob'] #not a good method
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-1a2b75b282a2> in <module>
# ----> 1 df3.loc[0] = ['Aryannn',16,'Noob'] #not a good method
#
# c:\essentials\python\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 692         iloc._setitem_with_indexer(indexer, value, self.name)
#     693
#     694     def _validate_key(self, key, axis: int):
#
# c:\essentials\python\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1633         if take_split_path:
#    1634             # We have to operate column-wise
# -> 1635             self._setitem_with_indexer_split_path(indexer, value, name)
#    1636         else:
#    1637             self._setitem_single_block(indexer, value, name)
#
# ...

# %%
df3
# Out:
#      Name  Umar SourceOfIncome  Umar
# 0   Aryan    18          Coder   NaN
# 1   Pawan    35   Bussinessman  69.0
# 2  Vishnu    17  Startup-owner   NaN

# %%
df3['Name']= df['Name'].map({'Pawan':'Pawann','Vishnu':'Vishnuuu'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\essentials\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-7f4f9c03445a> in <module>
# ...

# %%
df3['Name']
# Out:
# 0     Aryan
# 1     Pawan
# 2    Vishnu
# Name: Name, dtype: object

# %%
filt = df3['Name'] == 'Pawann'

# %%
df3.loc[filt,['Umar']] = 69

# %%
df3
# Out:
#      Name  Umar SourceOfIncome  Umar
# 0   Aryan    18          Coder   NaN
# 1   Pawan    35   Bussinessman  69.0
# 2  Vishnu    17  Startup-owner   NaN
