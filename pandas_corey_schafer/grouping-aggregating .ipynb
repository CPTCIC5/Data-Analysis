# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df['ConvertedCompYearly'].head(15)
# Out:
# 0     62268.0
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9     51552.0
# 10        NaN
# 11    46482.0
# 12    77290.0
# 13        NaN
# 14        NaN
# Name: ConvertedCompYearly, dtype: float64

# %%
df['ConvertedCompYearly'].median() #finds median of all data inside ConvertedCompYearly
# Out:
# 56211.0

# %%
df.median() #finds median of all int fields
# Out:
# ResponseId             41720.0
# CompTotal              67000.0
# ConvertedCompYearly    56211.0
# dtype: float64

# %%
df['ConvertedCompYearly'].count() #count() prints total no. of rows/queries inside this field
# Out:
# 46844

# %%
df['Trans'].value_counts() #value_counts() prints total no.of different results.
# Out:
# No                        77275
# Prefer not to say          1764
# Yes                        1035
# Or, in your own words:      604
# Name: Trans, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Liechtenstein                                               1
# Tuvalu                                                      1
# Brunei Darussalam                                           1
# Saint Vincent and the Grenadines                            1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 181, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#        ResponseId                              MainBranch          Employment  \
# 8               9          I am a developer by profession  Employed part-time
# 22             23  I am a student who is learning to code  Student, full-time
# 39             40  I am a student who is learning to code  Student, part-time
# 49             50  I am a student who is learning to code  Student, full-time
# 52             53          I am a developer by profession  Employed full-time
# ...           ...                                     ...                 ...
# 83399       83400          I am a developer by profession  Employed full-time
# 83406       83407  I am a student who is learning to code  Student, full-time
# 83410       83411  I am a student who is learning to code  Student, part-time
# 83411       83412          I am a developer by profession  Employed full-time
# 83417       83418          I am a developer by profession  Student, full-time
#
# ...

# %%
filt = df['Country'] == 'India'
df.loc[filt]
#df.loc[filt,'Age']
# Out:
#        ResponseId                              MainBranch          Employment  \
# 8               9          I am a developer by profession  Employed part-time
# 22             23  I am a student who is learning to code  Student, full-time
# 39             40  I am a student who is learning to code  Student, part-time
# 49             50  I am a student who is learning to code  Student, full-time
# 52             53          I am a developer by profession  Employed full-time
# ...           ...                                     ...                 ...
# 83399       83400          I am a developer by profession  Employed full-time
# 83406       83407  I am a student who is learning to code  Student, full-time
# 83410       83411  I am a student who is learning to code  Student, part-time
# 83411       83412          I am a developer by profession  Employed full-time
# 83417       83418          I am a developer by profession  Student, full-time
#
# ...

# %%
filt = df['Country'] == 'India'
#df.loc[filt].count()
#df.loc[filt]['Employment']
df.loc[filt]['Employment'].value_counts()
# Out:
# Employed full-time                                      6126
# Student, full-time                                      2229
# Independent contractor, freelancer, or self-employed     685
# Not employed, but looking for work                       544
# Student, part-time                                       423
# Not employed, and not looking for work                   175
# Employed part-time                                       161
# I prefer not to say                                      144
# Retired                                                    4
# Name: Employment, dtype: int64

# %%
country_grp['Age'].value_counts().loc['India']
# Out:
# Age
# 18-24 years old       4514
# 25-34 years old       4081
# Under 18 years old     861
# 35-44 years old        647
# 45-54 years old         94
# Prefer not to say       79
# 55-64 years old         12
# 65 years or older        7
# Name: Age, dtype: int64

# %%
df.loc['Country'].loc['India']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-bd386526ec1b> in <module>
# ----> 1 df.loc['Country'].loc['India']
#
# c:\essentials\python\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# c:\essentials\python\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# c:\essentials\python\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
# ...
